# %%
import numpy as np
import random

# %%
choices = ['r', 'p', 's']
def start(input):
  if input == 'r':
    return 'Rock'
  elif input == 's':
    return 'Scissors'
  elif input == 'p':
    return 'Paper'
  else:
    return 'Try again with an appropriate letter'

# %%
print('Rock: r, Paper: p, Scissors: s - Shoot!')
print('[Q] = Quit\n')
c = 1
ucw = 0
ccw = 0
while True:
   print(f'Game {str(c)}:')
   print('Please choose a letter:')
   uc = input()
   if uc == 'Q':
      print('Thanks for playing !')
      print(f'yor score is: {ucw} and computer score is {ccw}')
      break;
  
   ind = random.randint(0, 2)
   cc = choices[ind] 
 
   print(f'You chose: {start(uc)} and the computer chose:{start(cc)}')
   
   if uc == 'r' and cc == 's':
      print('You win, Rock beats Scissors')
      ucw = ucw+1
   elif uc == 'p' and cc== 'r':
      print('You win, Paper beats Rock')
      ucw = ucw+1
   elif uc=='s' and cc=='p':
      print('You win, Scissors beats Paper')
      ucw = ucw+1
   elif uc == 'r' and cc== 'p':
      print('Computer wins, Paper beats Rock')
      ccw = ccw+1
   elif uc == 'p' and cc == 's':
      print('Computer wins, Scissors beats Paper')
      ccw = ccw+1
   elif uc=='s' and cc=='r':
      print('Computer wins, Rock beats Scissors')
      ccw = ccw+1
   elif uc == cc:
      print('It is a tie !')
   else:
      print('Please enter your choice or [Q]')
      
   c = c + 1
   print(f'yor score is: {ucw} and computer score is {ccw}')
   print('\n')
# Out:
# Rock: r, Paper: p, Scissors: s - Shoot!
# [Q] = Quit
#
# Game 1:
# Please choose a letter:
# You chose: Scissors and the computer chose:Scissors
# It is a tie !
# yor score is: 0 and computer score is 0
#
#
# Game 2:
# Please choose a letter:
# You chose: Scissors and the computer chose:Scissors
# It is a tie !
# yor score is: 0 and computer score is 0
#
#
# Game 3:
# Please choose a letter:
# You chose: Scissors and the computer chose:Rock
# Computer wins, Rock beats Scissors
# yor score is: 0 and computer score is 1
#
#
# Game 4:
# Please choose a letter:
# You chose: Scissors and the computer chose:Rock
# Computer wins, Rock beats Scissors
# yor score is: 0 and computer score is 2
#
#
# Game 5:
# Please choose a letter:
# Thanks for playing !
# yor score is: 0 and computer score is 2

# %%
print('Rock, Paper, Scissors - Shoot!')
print('[Q] = Quit\n')
c = 1
ucw = 0
ccw = 0
while True:
   print(f'Game {str(c)}:')
   print('Please choose a letter:')
   uc = input()
   if uc == 'Q':
      print('Thanks for playing !')
      break;
  
   ind = random.randint(0, 2)
   cc = choices[ind] 
 
   print(f'You chose: {start(uc)} and the computer chose:{start(cc)}')
   
   if uc == 'R' or uc == 'r' or uc == 'Rock' or uc =='rock' and cc == 'S' or cc == 's' or\
      cc == 'Scissors' or cc == 'scissors':
      print('You win, Rock beats Scissors')
      ucw = ucw+1
   elif uc == 'P' or uc == 'p' or uc == 'Paper' or uc == "paper" and cc == 'R' or\
      cc== 'r' or cc == 'Rock' or cc=='rock':
      print('You win, Paper beats Rock')
      ucw = ucw+1
   elif uc == 'S' or uc=='s' or uc=='Scissors' or uc=='scissors' and cc == 'P' or\
      cc=='p' or cc=='Paper' or cc=='paper':
      print('You win, Scissors beats Paper')
      ucw = ucw+1
   elif uc == 'R' or uc == 'r' or uc == 'Rock' or uc =='rock' and cc == 'P' or\
      cc== 'p' or cc== 'Paper' or cc=='paper':
      print('Computer wins, Paper beats Rock')
      ccw = ccw+1
   elif uc == 'P' or uc == 'p' or uc == 'Paper' or uc == "paper" and cc == 'S' or\
      cc == 's' or cc=='Scissors' or cc == 'scissors':
      print('Computer wins, Scissors beats Paper')
      ccw = ccw+1
   elif uc == 'S' or uc=='s' or uc=='Scissors' or uc=='scissors'  and cc == 'R' or\
      cc=='r' or cc=='Rock' or cc=='rock':
      print('Computer wins, Rock beats Scissors')
      ccw = ccw+1
   elif uc == cc:
      print('It is a tie !')
   else:
      print('Please enter your choice or [Q]')
      
   c = c + 1
   print(f'yor score is: {ucw} and computer score is {ccw}')
   print('\n')
# Out:
# Rock, Paper, Scissors - Shoot!
# [Q] = Quit
#
# Game 1:
# Please choose a letter:
# You chose: Rock and the computer chose:Rock
# You win, Rock beats Scissors
# yor score is: 1 and computer score is 0
#
#
# Game 2:
# Please choose a letter:
# You chose: Rock and the computer chose:Rock
# You win, Rock beats Scissors
# yor score is: 2 and computer score is 0
#
#
# Game 3:
# Please choose a letter:
# You chose: Rock and the computer chose:Rock
# You win, Rock beats Scissors
# yor score is: 3 and computer score is 0
#
#
# Game 4:
# Please choose a letter:
# Thanks for playing !
